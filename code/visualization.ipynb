# %% [markdown]
# ### 1 Preparation

# %%
import pandas as pd

# %%
df=pd.read_csv('E:/MSDS/2024Fall/STAT628/module3/combined_data.csv')

# %%
df.head()
# Out:
#    DayOfWeek Origin Dest              DepTime           CRSArrTime  \
# 0          4    BDL  RDU  2018-11-15 06:00:00  2018-11-15 07:50:00
# 1          5    BDL  RDU  2018-11-16 06:31:00  2018-11-16 07:50:00
# 2          2    BDL  RDU  2018-11-20 05:58:00  2018-11-20 07:50:00
# 3          6    BDL  RDU  2018-11-24 05:58:00  2018-11-24 07:50:00
# 4          1    BDL  RDU  2018-11-26 05:56:00  2018-11-26 07:50:00
#
#                ArrTime           CRSDepTime  Cancelled  \
# 0  2018-11-15 08:00:00  2018-11-15 06:00:00          0
# 1  2018-11-16 08:59:00  2018-11-16 06:00:00          0
# 2  2018-11-20 07:50:00  2018-11-20 06:00:00          0
# 3  2018-11-24 07:50:00  2018-11-24 06:00:00          0
# 4  2018-11-26 07:53:00  2018-11-26 06:00:00          0
#
#    Departure_HourlyDewPointTemperature  Departure_HourlyDryBulbTemperature  \
# 0                                -11.1                                -5.6
# 1                                  0.0                                 0.6
# 2                                  1.1                                 1.7
# 3                                -13.3                                -6.1
# 4                                  2.2                                 2.2
#
#    ...  Airline_AS  Airline_B6  Airline_DL  Airline_F9  Airline_G4  \
# 0  ...       False       False        True       False       False
# 1  ...       False       False        True       False       False
# 2  ...       False       False        True       False       False
# 3  ...       False       False        True       False       False
# 4  ...       False       False        True       False       False
#
#    Airline_HA  Airline_NK  Airline_UA  Airline_WN  delay_time
# 0       False       False       False       False       -10.0
# 1       False       False       False       False       -69.0
# 2       False       False       False       False         0.0
# 3       False       False       False       False         0.0
# 4       False       False       False       False        -3.0
#
# [5 rows x 69 columns]

# %%
df.columns
# Out:
# Index(['DayOfWeek', 'Origin', 'Dest', 'DepTime', 'CRSArrTime', 'ArrTime',
#        'CRSDepTime', 'Cancelled', 'Departure_HourlyDewPointTemperature',
#        'Departure_HourlyDryBulbTemperature', 'Departure_HourlyPrecipitation',
#        'Departure_HourlyRelativeHumidity', 'Departure_HourlySeaLevelPressure',
#        'Departure_HourlyStationPressure', 'Departure_HourlyVisibility',
#        'Departure_HourlyWetBulbTemperature', 'Departure_HourlyWindDirection',
#        'Departure_HourlyWindSpeed', 'Arrival_HourlyDewPointTemperature',
#        'Arrival_HourlyDryBulbTemperature', 'Arrival_HourlyPrecipitation',
#        'Arrival_HourlyRelativeHumidity', 'Arrival_HourlySeaLevelPressure',
#        'Arrival_HourlyStationPressure', 'Arrival_HourlyVisibility',
#        'Arrival_HourlyWetBulbTemperature', 'Arrival_HourlyWindDirection',
#        'Arrival_HourlyWindSpeed', 'Dep_10', 'Dep_BKN', 'Dep_CLR', 'Dep_FEW',
#        'Dep_OVC', 'Dep_SCT', 'Dep_VV', 'Arr_10', 'Arr_BKN', 'Arr_CLR',
#        'Arr_FEW', 'Arr_OVC', 'Arr_SCT', 'Arr_VV', 'DepTime_num',
#        'CRSArrTime_num', 'ArrTime_num', 'CRSDepTime_num',
#        'CRSDepTime_Dest_num', 'Year', 'ArrTimeOfDay_afternoon',
#        'ArrTimeOfDay_evening', 'ArrTimeOfDay_morning', 'ArrTimeOfDay_night',
#        'DepTimeOfDay_afternoon', 'DepTimeOfDay_evening',
#        'DepTimeOfDay_morning', 'DepTimeOfDay_night', 'Origin_Label',
#        'Dest_Label', 'Airline_AA', 'Airline_AS', 'Airline_B6', 'Airline_DL',
#        'Airline_F9', 'Airline_G4', 'Airline_HA', 'Airline_NK', 'Airline_UA',
#        'Airline_WN', 'delay_time'],
#       dtype='object')

# %%
filtered_df=df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filtered_df.head()
# Out:
#    DayOfWeek Origin Dest              DepTime           CRSArrTime  \
# 0          4    BDL  RDU  2018-11-15 06:00:00  2018-11-15 07:50:00
# 1          5    BDL  RDU  2018-11-16 06:31:00  2018-11-16 07:50:00
# 2          2    BDL  RDU  2018-11-20 05:58:00  2018-11-20 07:50:00
# 3          6    BDL  RDU  2018-11-24 05:58:00  2018-11-24 07:50:00
# 4          1    BDL  RDU  2018-11-26 05:56:00  2018-11-26 07:50:00
#
#                ArrTime           CRSDepTime  Cancelled  \
# 0  2018-11-15 08:00:00  2018-11-15 06:00:00          0
# 1  2018-11-16 08:59:00  2018-11-16 06:00:00          0
# 2  2018-11-20 07:50:00  2018-11-20 06:00:00          0
# 3  2018-11-24 07:50:00  2018-11-24 06:00:00          0
# 4  2018-11-26 07:53:00  2018-11-26 06:00:00          0
#
#    Departure_HourlyDewPointTemperature  Departure_HourlyDryBulbTemperature  \
# 0                                -11.1                                -5.6
# 1                                  0.0                                 0.6
# 2                                  1.1                                 1.7
# 3                                -13.3                                -6.1
# 4                                  2.2                                 2.2
#
#    ...  Airline_AS  Airline_B6  Airline_DL  Airline_F9  Airline_G4  \
# 0  ...       False       False        True       False       False
# 1  ...       False       False        True       False       False
# 2  ...       False       False        True       False       False
# 3  ...       False       False        True       False       False
# 4  ...       False       False        True       False       False
#
#    Airline_HA  Airline_NK  Airline_UA  Airline_WN  delay_time
# 0       False       False       False       False       -10.0
# 1       False       False       False       False       -69.0
# 2       False       False       False       False         0.0
# 3       False       False       False       False         0.0
# 4       False       False       False       False        -3.0
#
# [5 rows x 69 columns]

# %%
filtered_df['CRSDepTime'] = pd.to_datetime(filtered_df['CRSDepTime'])

# %%
filtered_df['CRSArrTime'] = pd.to_datetime(filtered_df['CRSArrTime'])

# %% [markdown]
# ### 2 visualization

# %% [markdown]
# #### 2.1 Average Delay Time by Airline in 2023 Holiday season

# %%
data = filtered_df[filtered_df['CRSDepTime']>= '2023-11-01']

# %%
data.head()
# Out:
#          DayOfWeek Origin Dest              DepTime          CRSArrTime  \
# 5783202          4    IAH  LGA  2023-11-02 18:30:00 2023-11-02 22:58:00
# 5783203          4    MSY  IAH  2023-11-02 15:55:00 2023-11-02 17:25:00
# 5783204          4    ORD  DCA  2023-11-02 17:48:00 2023-11-02 20:51:00
# 5783205          4    SMF  ORD  2023-11-02 10:32:00 2023-11-02 16:35:00
# 5783206          4    SFO  BOS  2023-11-02 08:25:00 2023-11-02 17:06:00
#
#                      ArrTime          CRSDepTime  Cancelled  \
# 5783202  2023-11-02 23:03:00 2023-11-02 18:34:00          0
# 5783203  2023-11-02 17:21:00 2023-11-02 16:01:00          0
# 5783204  2023-11-02 20:26:00 2023-11-02 17:55:00          0
# 5783205  2023-11-02 16:38:00 2023-11-02 10:30:00          0
# 5783206  2023-11-02 16:58:00 2023-11-02 08:30:00          0
#
#          Departure_HourlyDewPointTemperature  \
# 5783202                                  5.0
# 5783203                                 10.6
# 5783204                                  0.0
# 5783205                                  7.2
# 5783206                                  9.4
#
#          Departure_HourlyDryBulbTemperature  ...  Airline_AS  Airline_B6  \
# 5783202                                13.9  ...       False       False
# 5783203                                18.9  ...       False       False
# 5783204                                11.7  ...       False       False
# 5783205                                18.3  ...       False       False
# 5783206                                15.6  ...       False       False
#
#          Airline_DL  Airline_F9  Airline_G4  Airline_HA  Airline_NK  \
# 5783202       False       False       False       False       False
# 5783203       False       False       False       False       False
# 5783204       False       False       False       False       False
# 5783205       False       False       False       False       False
# 5783206       False       False       False       False       False
#
#          Airline_UA  Airline_WN  delay_time
# 5783202        True       False        -5.0
# 5783203        True       False         4.0
# 5783204        True       False        25.0
# 5783205        True       False        -3.0
# 5783206        True       False         8.0
#
# [5 rows x 69 columns]

# %%
data['delay'] = (data['CRSArrTime_num'] - data['ArrTime_num'])/60
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\1782548707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['delay'] = (data['CRSArrTime_num'] - data['ArrTime_num'])/60

# %%
from matplotlib.patches import Patch
avg_delay_by_airline = {}

for col in df.columns[-11:-1]: 
    airline_data = data[data[col] == 1]

    avg_delay = airline_data['delay'].mean()
    avg_cancelled_rate = airline_data['Cancelled'].mean() * 100 
    avg_delay_by_airline[col] = {'Average_Delay': avg_delay, 'Average_Cancelled_Rate': avg_cancelled_rate}


avg_delay_df = pd.DataFrame.from_dict(avg_delay_by_airline, orient='index').reset_index()
avg_delay_df = avg_delay_df.rename(columns={'index': 'Airline'})


avg_delay_df = avg_delay_df.sort_values(by='Average_Delay', ascending=False)

colors = {
    'Airline_AS': '#002240',
    'Airline_HA': '#003366',
    'Airline_UA': '#004C99',
    'Airline_WN': '#0066CC',
    'Airline_AA': '#3399FF',
    'Airline_NK': '#66B2FF',
    'Airline_B6': '#99CCFF',
    'Airline_F9': '#CCE6FF',
    'Airline_G4': '#E6F7FF',
    'Airline_DL': '#B0E0E6'
}
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_delay_df, x="Airline", y="Average_Delay", palette=colors)
plt.title("Average Delay Time by Airline in 2023 Holiday season")
plt.xlabel("Airline")
plt.ylabel("Average Delay (minutes)")

legend_labels = [Patch(color=color, label=airline) for airline, color in colors.items()]
plt.legend(handles=legend_labels, title="Airline")
plt.savefig('Average Delay Time by Airline in 2023 Holiday season.png', dpi=300)
plt.show()

# %%
avg_delay_by_airline = {}

for col in df.columns[-11:-1]: 
    avg_delay_by_airline[col] = data.loc[data[col] == 1, 'Cancelled'].mean()*100

avg_delay_df = pd.DataFrame(list(avg_delay_by_airline.items()), columns=['Airline', 'Cancelled_rate'])
avg_delay_df = avg_delay_df.sort_values(by='Cancelled_rate', ascending=False)

colors = {
    'Airline_AS': '#002240',
    'Airline_HA': '#003366',
    'Airline_UA': '#004C99',
    'Airline_WN': '#0066CC',
    'Airline_AA': '#3399FF',
    'Airline_NK': '#66B2FF',
    'Airline_B6': '#99CCFF',
    'Airline_F9': '#CCE6FF',
    'Airline_G4': '#E6F7FF',
    'Airline_DL': '#B0E0E6'
}

plt.figure(figsize=(10, 6))
sns.barplot(data=avg_delay_df, x="Airline", y="Cancelled_rate", palette=colors)
plt.title("Cancelled Rate by Airline in 2023 Holiday season")
plt.xlabel("Airline")
plt.ylabel("Cancelled Rate(%)")

legend_labels = [Patch(color=color, label=airline) for airline, color in colors.items()]
plt.legend(handles=legend_labels, title="Airline")
plt.savefig('Cancelled Rate by Airline in 2023 Holiday season.png', dpi=300)
plt.show()

# %% [markdown]
# #### 2.2 Cancelled rate by day of week in 2023 Holiday season (DepTime)

# %%
data['Hour'] =data['CRSDepTime'].dt.hour  
data['DayOfWeek'] = data['CRSDepTime'].dt.day_name() 

day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
data['DayOfWeek'] = pd.Categorical(data['DayOfWeek'], categories=day_order, ordered=True)

cancel_by_hour = data.groupby(['Hour', 'DayOfWeek'])['Cancelled'].mean().reset_index()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\2132628347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Hour'] =data['CRSDepTime'].dt.hour
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\2132628347.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DayOfWeek'] = data['CRSDepTime'].dt.day_name()
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\2132628347.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DayOfWeek'] = pd.Categorical(data['DayOfWeek'], categories=day_order, ordered=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\2132628347.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cancel_by_hour = data.groupby(['Hour', 'DayOfWeek'])['Cancelled'].mean().reset_index()

# %%
cancel_by_hour
# Out:
#      Hour  DayOfWeek  Cancelled
# 0       0     Monday   0.007842
# 1       0    Tuesday   0.007040
# 2       0  Wednesday   0.006700
# 3       0   Thursday   0.002953
# 4       0     Friday   0.003966
# ..    ...        ...        ...
# 163    23  Wednesday   0.005740
# 164    23   Thursday   0.003609
# 165    23     Friday   0.006809
# 166    23   Saturday   0.011353
# 167    23     Sunday   0.013846
#
# [168 rows x 3 columns]

# %%
sns.lineplot(data=cancel_by_hour, x='Hour', y='Cancelled', hue='DayOfWeek', marker="o")

plt.xlim(-1, 24)
plt.title('Cancelled Rate by Scheduled Departure Time during 2023 Holiday Season')
plt.xlabel('Scheduled Departure Time(Hour)')
plt.ylabel('Cancellation Rate')
plt.legend(title='Day of Week')
plt.savefig('Cancelled Rate by Scheduled Departure Time during 2023 Holiday Season.png', dpi=300)
plt.show()
# Out:
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %% [markdown]
# #### 2.3 Average Delay Time by day of week in 2023 Holiday season (CRSDepTime)

# %%
data['Hour'] =data['CRSDepTime'].dt.hour 
data['DayOfWeek'] = data['CRSDepTime'].dt.day_name() 
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
data['DayOfWeek'] = pd.Categorical(data['DayOfWeek'], categories=day_order, ordered=True)

delay_by_hour = data.groupby(['Hour', 'DayOfWeek'])['delay'].mean().reset_index()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\506344012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Hour'] =data['CRSDepTime'].dt.hour
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\506344012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DayOfWeek'] = data['CRSDepTime'].dt.day_name()
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\506344012.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DayOfWeek'] = pd.Categorical(data['DayOfWeek'], categories=day_order, ordered=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_13548\506344012.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   delay_by_hour = data.groupby(['Hour', 'DayOfWeek'])['delay'].mean().reset_index()

# %%
sns.lineplot(data=delay_by_hour, x='Hour', y='delay', hue='DayOfWeek', marker="o")

plt.xlim(-1, 24)
plt.title('Average Delay Time by Scheduled Departure Time during 2023 Holiday Season')
plt.xlabel('Scheduled Departure Time (Hour)')
plt.ylabel("Average Delay (minutes)")
plt.legend(title='Day of Week')
plt.savefig('Average Delay Time by Scheduled Departure Time during 2023 Holiday Season.png', dpi=300)
plt.show()
# Out:
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
